# %% [markdown]
# ## Package installation

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.display import clear_output
# !pip install scikit-learn==0.20.2 --user -q
# !pip install --upgrade numpy --no-cache | tail -n 1
# !pip install --upgrade SciPy --no-cache | tail -n 1
# !pip install lime --no-cache | tail -n 1
# !pip install ibm_watson_openscale==3.0.3 | tail -n 1
# !pip install ibm_wos_utils | tail -n 1
clear_output(wait=False)
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/envs/Python-3.9/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/setup.py'"'"'; __file__='"'"'/tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/1000810000/pip-wheel-e9m958yf
#        cwd: /tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/
#   Complete output (1908 lines):
#   Partial import of sklearn during the build process.
#   /tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/setup.py:242: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     from numpy.distutils.core import setup
#   INFO: blas_opt_info:
#   INFO: blas_armpl_info:
#   INFO: customize UnixCCompiler
#   INFO:   libraries armpl_lp64_mp not found in ['/opt/conda/envs/Python-3.9/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blas_mkl_info:
#   INFO:   libraries mkl_rt not found in ['/opt/conda/envs/Python-3.9/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blis_info:
#   INFO:   libraries blis not found in ['/opt/conda/envs/Python-3.9/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_info:
#   INFO: C compiler: gcc -pthread -B /opt/conda/envs/Python-3.9/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/Python-3.9/include -I/opt/conda/envs/Python-3.9/include -fPIC -O2 -isystem /opt/conda/envs/Python-3.9/include -fPIC
#
#   creating /tmp/1000810000/tmplv3vavim/tmp
#   creating /tmp/1000810000/tmplv3vavim/tmp/1000810000
#   creating /tmp/1000810000/tmplv3vavim/tmp/1000810000/tmplv3vavim
#   INFO: compile options: '-c'
#   INFO: gcc: /tmp/1000810000/tmplv3vavim/source.c
#   INFO: gcc -pthread -B /opt/conda/envs/Python-3.9/compiler_compat /tmp/1000810000/tmplv3vavim/tmp/1000810000/tmplv3vavim/source.o -L/opt/conda/envs/Python-3.9/lib -lopenblas -o /tmp/1000810000/tmplv3vavim/a.out
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: warning: libm.so.6, needed by /opt/conda/envs/Python-3.9/lib/libopenblas.so, not found (try using -rpath or -rpath-link)
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: warning: libquadmath.so.0, needed by /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4, not found (try using -rpath or -rpath-link)
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atanh@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sinhq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acos@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `sin@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `cabsl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asinl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asinh@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `exp@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `sincosf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atanl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `log10l@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `erfcq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acosq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asin@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tanq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `csin@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `jnq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atan@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `roundl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `jnf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `strtoflt128@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `fmod@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atan2q@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `nanq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `csqrt@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sinl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `cosl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `atan2@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `roundf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `ccosf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `expl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `expq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `clogf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `cabs@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `clog@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `log@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `cexpq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `cabsf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `jnl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atanq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `jn@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atanf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atanhq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `csinf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `clogl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `lroundq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `truncq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `csqrtl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tanl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `fmodl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `ccos@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `csinq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sqrtl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `ccosl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atan2l@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `cos@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `coshl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `cosh@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sinhf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `csqrtq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `coshq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acosh@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `ynq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asinhl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `ynf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `yn@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tanhl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `ccosq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `powf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asinq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tanh@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `quadmath_snprintf@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tanhq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `sinf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `truncf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `fmodf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `pow@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asinhf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acosl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acoshl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `coshf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `clogq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `atan2f@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `roundq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `expf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `lround@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `csqrtf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tanf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `logl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `fmodq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `round@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `truncl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `copysignq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `fabsq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sqrtq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `log10@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asinf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sinhl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `sqrtf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atanhf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `log10q@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `logf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `cosf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sinh@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tan@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `log10f@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `cosq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `trunc@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `asinhq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `lroundl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acoshf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `logq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `cexp@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acosf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `sqrt@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `csinl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `acoshq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `sincos@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `lroundf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `ynl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `atanhl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `cexpl@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `tanhf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `sinq@QUADMATH_1.0'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/libopenblas.so: undefined reference to `cexpf@GLIBC_2.2.5'
#   /opt/conda/envs/Python-3.9/compiler_compat/ld: /opt/conda/envs/Python-3.9/lib/./libgfortran.so.4: undefined reference to `cabsq@QUADMATH_1.0'
#   collect2: error: ld returned 1 exit status
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: accelerate_info:
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_3_10_blas_threads_info:
#   INFO: Setting PTATLAS=ATLAS
#   INFO:   libraries tatlas not found in ['/opt/conda/envs/Python-3.9/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_3_10_blas_info:
#   INFO:   libraries satlas not found in ['/opt/conda/envs/Python-3.9/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_blas_threads_info:
#   INFO: Setting PTATLAS=ATLAS
#   INFO:   libraries ptf77blas,ptcblas,atlas not found in ['/opt/conda/envs/Python-3.9/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_blas_info:
#   INFO:   libraries f77blas,cblas,atlas not found in ['/opt/conda/envs/Python-3.9/lib', '/usr/local/lib64', '/usr/local/lib', '/usr/lib64/sse2', '/usr/lib64', '/usr/lib/sse2', '/usr/lib', '/usr/lib/sse2', '/usr/lib/']
#   INFO:   NOT AVAILABLE
#   INFO:
#   /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/numpy/distutils/system_info.py:2077: UserWarning:
#       Optimized (vendor) Blas libraries are not found.
#       Falls back to netlib Blas library which has worse performance.
#       A better performance should be easily gained by switching
#       Blas library.
#     if self._calc_info(blas):
#   INFO: blas_info:
#   INFO: C compiler: gcc -pthread -B /opt/conda/envs/Python-3.9/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/Python-3.9/include -I/opt/conda/envs/Python-3.9/include -fPIC -O2 -isystem /opt/conda/envs/Python-3.9/include -fPIC
#
#   creating /tmp/1000810000/tmprnndd6xo/tmp
#   creating /tmp/1000810000/tmprnndd6xo/tmp/1000810000
#   creating /tmp/1000810000/tmprnndd6xo/tmp/1000810000/tmprnndd6xo
#   INFO: compile options: '-I/usr/local/include -I/opt/conda/envs/Python-3.9/include -c'
#   INFO: gcc: /tmp/1000810000/tmprnndd6xo/source.c
#   /tmp/1000810000/tmprnndd6xo/source.c:1:10: fatal error: cblas.h: No such file or directory
#    #include <cblas.h>
#             ^~~~~~~~~
#   compilation terminated.
#   INFO:   FOUND:
#   INFO:     libraries = ['blas', 'blas']
#   INFO:     library_dirs = ['/opt/conda/envs/Python-3.9/lib']
#   INFO:     include_dirs = ['/usr/local/include', '/opt/conda/envs/Python-3.9/include']
#   INFO:
#   INFO:   FOUND:
#   INFO:     define_macros = [('NO_ATLAS_INFO', 1)]
#   INFO:     libraries = ['blas', 'blas']
#   INFO:     library_dirs = ['/opt/conda/envs/Python-3.9/lib']
#   INFO:     include_dirs = ['/usr/local/include', '/opt/conda/envs/Python-3.9/include']
#   INFO:
#   sklearn/setup.py:73: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     warnings.warn(BlasNotFoundError.__doc__)
#   running bdist_wheel
#   running build
#   running config_cc
#   INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   INFO: build_src
#   INFO: building library "libsvm-skl" sources
#   INFO: building library "cblas" sources
#   INFO: building extension "sklearn.__check_build._check_build" sources
#   INFO: building extension "sklearn.cluster._dbscan_inner" sources
#   INFO: building extension "sklearn.cluster._hierarchical" sources
#   INFO: building extension "sklearn.cluster._k_means_elkan" sources
#   INFO: building extension "sklearn.cluster._k_means" sources
#   INFO: building extension "sklearn.datasets._svmlight_format" sources
#   INFO: building extension "sklearn.decomposition._online_lda" sources
#   INFO: building extension "sklearn.decomposition.cdnmf_fast" sources
#   INFO: building extension "sklearn.ensemble._gradient_boosting" sources
#   INFO: building extension "sklearn.feature_extraction._hashing" sources
#   INFO: building extension "sklearn.manifold._utils" sources
#   INFO: building extension "sklearn.manifold._barnes_hut_tsne" sources
#   INFO: building extension "sklearn.metrics.cluster.expected_mutual_info_fast" sources
#   INFO: building extension "sklearn.metrics.pairwise_fast" sources
#   INFO: building extension "sklearn.neighbors.ball_tree" sources
#   INFO: building extension "sklearn.neighbors.kd_tree" sources
#   INFO: building extension "sklearn.neighbors.dist_metrics" sources
#   INFO: building extension "sklearn.neighbors.typedefs" sources
#   INFO: building extension "sklearn.neighbors.quad_tree" sources
#   INFO: building extension "sklearn.tree._tree" sources
#   INFO: building extension "sklearn.tree._splitter" sources
#   INFO: building extension "sklearn.tree._criterion" sources
#   INFO: building extension "sklearn.tree._utils" sources
#   INFO: building extension "sklearn.svm.libsvm" sources
#   INFO: building extension "sklearn.svm.liblinear" sources
#   INFO: building extension "sklearn.svm.libsvm_sparse" sources
#   INFO: building extension "sklearn._isotonic" sources
#   INFO: building extension "sklearn.linear_model.cd_fast" sources
#   INFO: building extension "sklearn.linear_model.sgd_fast" sources
#   INFO: building extension "sklearn.linear_model.sag_fast" sources
#   INFO: building extension "sklearn.utils.sparsefuncs_fast" sources
#   INFO: building extension "sklearn.utils.arrayfuncs" sources
#   INFO: building extension "sklearn.utils.murmurhash" sources
#   INFO: building extension "sklearn.utils.lgamma" sources
#   INFO: building extension "sklearn.utils.graph_shortest_path" sources
#   INFO: building extension "sklearn.utils.fast_dict" sources
#   INFO: building extension "sklearn.utils.seq_dataset" sources
#   INFO: building extension "sklearn.utils.weight_vector" sources
#   INFO: building extension "sklearn.utils._random" sources
#   INFO: building extension "sklearn.utils._logistic_sigmoid" sources
#   INFO: building data_files sources
#   INFO: build_src: building npy-pkg config files
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.9
#   creating build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/__init__.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/_config.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/base.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/calibration.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/discriminant_analysis.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/dummy.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/exceptions.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/impute.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/isotonic.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/kernel_approximation.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/kernel_ridge.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/multiclass.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/multioutput.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/naive_bayes.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/pipeline.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/random_projection.py -> build/lib.linux-x86_64-3.9/sklearn
#   copying sklearn/setup.py -> build/lib.linux-x86_64-3.9/sklearn
#   creating build/lib.linux-x86_64-3.9/sklearn/__check_build
#   copying sklearn/__check_build/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/__check_build
#   copying sklearn/__check_build/setup.py -> build/lib.linux-x86_64-3.9/sklearn/__check_build
#   creating build/lib.linux-x86_64-3.9/sklearn/_build_utils
#   copying sklearn/_build_utils/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/_build_utils
#   creating build/lib.linux-x86_64-3.9/sklearn/compose
#   copying sklearn/compose/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/compose
#   copying sklearn/compose/_column_transformer.py -> build/lib.linux-x86_64-3.9/sklearn/compose
#   copying sklearn/compose/_target.py -> build/lib.linux-x86_64-3.9/sklearn/compose
#   creating build/lib.linux-x86_64-3.9/sklearn/compose/tests
#   copying sklearn/compose/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/compose/tests
#   copying sklearn/compose/tests/test_column_transformer.py -> build/lib.linux-x86_64-3.9/sklearn/compose/tests
#   copying sklearn/compose/tests/test_target.py -> build/lib.linux-x86_64-3.9/sklearn/compose/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/elliptic_envelope.py -> build/lib.linux-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/empirical_covariance_.py -> build/lib.linux-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/graph_lasso_.py -> build/lib.linux-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/robust_covariance.py -> build/lib.linux-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/shrunk_covariance_.py -> build/lib.linux-x86_64-3.9/sklearn/covariance
#   creating build/lib.linux-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_covariance.py -> build/lib.linux-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_elliptic_envelope.py -> build/lib.linux-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_graph_lasso.py -> build/lib.linux-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_graphical_lasso.py -> build/lib.linux-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_robust_covariance.py -> build/lib.linux-x86_64-3.9/sklearn/covariance/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/cca_.py -> build/lib.linux-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/pls_.py -> build/lib.linux-x86_64-3.9/sklearn/cross_decomposition
#   creating build/lib.linux-x86_64-3.9/sklearn/cross_decomposition/tests
#   copying sklearn/cross_decomposition/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/cross_decomposition/tests
#   copying sklearn/cross_decomposition/tests/test_pls.py -> build/lib.linux-x86_64-3.9/sklearn/cross_decomposition/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/base.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/from_model.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/mutual_info_.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/rfe.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/univariate_selection.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/variance_threshold.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection
#   creating build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_base.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_chi2.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_feature_select.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_from_model.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_mutual_info.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_rfe.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_variance_threshold.py -> build/lib.linux-x86_64-3.9/sklearn/feature_selection/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/correlation_models.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/gpc.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/gpr.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/kernels.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/regression_models.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process
#   creating build/lib.linux-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/test_gpc.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/test_gpr.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/test_kernels.py -> build/lib.linux-x86_64-3.9/sklearn/gaussian_process/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/base.py -> build/lib.linux-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/bayesian_mixture.py -> build/lib.linux-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/gaussian_mixture.py -> build/lib.linux-x86_64-3.9/sklearn/mixture
#   creating build/lib.linux-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/test_bayesian_mixture.py -> build/lib.linux-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/test_gaussian_mixture.py -> build/lib.linux-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/test_mixture.py -> build/lib.linux-x86_64-3.9/sklearn/mixture/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/_search.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/_split.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/_validation.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection
#   creating build/lib.linux-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/common.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/test_search.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/test_split.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/test_validation.py -> build/lib.linux-x86_64-3.9/sklearn/model_selection/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/_base.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/_stochastic_optimizers.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/multilayer_perceptron.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/rbm.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network
#   creating build/lib.linux-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/test_mlp.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/test_rbm.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/test_stochastic_optimizers.py -> build/lib.linux-x86_64-3.9/sklearn/neural_network/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_discretization.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_encoders.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_function_transformer.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/base.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/data.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/imputation.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/label.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing
#   creating build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_base.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_common.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_data.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_discretization.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_encoders.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_function_transformer.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_imputation.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_label.py -> build/lib.linux-x86_64-3.9/sklearn/preprocessing/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/semi_supervised
#   copying sklearn/semi_supervised/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/semi_supervised
#   copying sklearn/semi_supervised/label_propagation.py -> build/lib.linux-x86_64-3.9/sklearn/semi_supervised
#   creating build/lib.linux-x86_64-3.9/sklearn/semi_supervised/tests
#   copying sklearn/semi_supervised/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/semi_supervised/tests
#   copying sklearn/semi_supervised/tests/test_label_propagation.py -> build/lib.linux-x86_64-3.9/sklearn/semi_supervised/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_feature_agglomeration.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/affinity_propagation_.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/bicluster.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/birch.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/dbscan_.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/hierarchical.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/k_means_.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/mean_shift_.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/setup.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/spectral.py -> build/lib.linux-x86_64-3.9/sklearn/cluster
#   creating build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/common.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_affinity_propagation.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_bicluster.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_birch.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_dbscan.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_feature_agglomeration.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_hierarchical.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_k_means.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_mean_shift.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_spectral.py -> build/lib.linux-x86_64-3.9/sklearn/cluster/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/base.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/california_housing.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/covtype.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/kddcup99.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/lfw.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/mlcomp.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/mldata.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/olivetti_faces.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/openml.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/rcv1.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/samples_generator.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/setup.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/species_distributions.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/svmlight_format.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/twenty_newsgroups.py -> build/lib.linux-x86_64-3.9/sklearn/datasets
#   creating build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_20news.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_base.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_california_housing.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_common.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_covtype.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_kddcup99.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_lfw.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_mldata.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_openml.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_rcv1.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_samples_generator.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_svmlight_format.py -> build/lib.linux-x86_64-3.9/sklearn/datasets/tests
#   creating build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/base.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/dict_learning.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/factor_analysis.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/fastica_.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/incremental_pca.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/kernel_pca.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/nmf.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/online_lda.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/pca.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/setup.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/sparse_pca.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/truncated_svd.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition
#   creating build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/__init__.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_dict_learning.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_factor_analysis.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_fastica.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_incremental_pca.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_kernel_pca.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_nmf.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_online_lda.py -> build/lib.linux-x86_64-3.9/sklearn/decomposition/tests
# ...
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#      #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                ^
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#            PyUnicode_WSTR_LENGTH(op) :                    \
#            ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:26231:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                               ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#      static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#            ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                                                         ^
#     sklearn/cluster/_hierarchical.cpp:26231:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                               ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#      Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                                                  ^~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#            ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                                                         ^
#     sklearn/cluster/_hierarchical.cpp:26231:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                               ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#      Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                                                  ^~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#      #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                ^
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#             PyUnicode_WSTR_LENGTH(op)))
#             ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:26231:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                               ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#      static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#      #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                ^
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#             PyUnicode_WSTR_LENGTH(op)))
#             ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:26231:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                               ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#      static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#      #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                ^
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#            PyUnicode_WSTR_LENGTH(op) :                    \
#            ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:26231:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#      static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#      #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                ^
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#            PyUnicode_WSTR_LENGTH(op) :                    \
#            ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:26231:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#      static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#            ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                                                         ^
#     sklearn/cluster/_hierarchical.cpp:26231:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#      Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                                                  ^~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#            ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                                                         ^
#     sklearn/cluster/_hierarchical.cpp:26231:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here
#      Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                                                  ^~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#      #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                ^
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#             PyUnicode_WSTR_LENGTH(op)))
#             ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:26231:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#      static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#      #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                                                                ^
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#             PyUnicode_WSTR_LENGTH(op)))
#             ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:26231:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#                              (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                ^~~~~~~~~~~~~~~~~~
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here
#      static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp: In function ‘PyObject* __Pyx_decode_c_string(const char*, Py_ssize_t, Py_ssize_t, const char*, const char*, PyObject* (*)(const char*, Py_ssize_t, const char*))’:
#     sklearn/cluster/_hierarchical.cpp:29333:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#              return PyUnicode_FromUnicode(NULL, 0);
#                                                  ^
#     In file included from /opt/conda/envs/Python-3.9/include/python3.9/unicodeobject.h:1026,
#                      from /opt/conda/envs/Python-3.9/include/python3.9/Python.h:93,
#                      from sklearn/cluster/_hierarchical.cpp:27:
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:551:42: note: declared here
#      Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#                                               ^~~~~~~~~~~~~~~~~~~~~
#     sklearn/cluster/_hierarchical.cpp:29333:45: warning: ‘PyObject* PyUnicode_FromUnicode(const Py_UNICODE*, Py_ssize_t)’ is deprecated [-Wdeprecated-declarations]
#              return PyUnicode_FromUnicode(NULL, 0);
#                                                  ^
#     In file included from /opt/conda/envs/Python-3.9/include/python3.9/unicodeobject.h:1026,
#                      from /opt/conda/envs/Python-3.9/include/python3.9/Python.h:93,
#                      from sklearn/cluster/_hierarchical.cpp:27:
#     /opt/conda/envs/Python-3.9/include/python3.9/cpython/unicodeobject.h:551:42: note: declared here
#      Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#                                               ^~~~~~~~~~~~~~~~~~~~~
#     error: Command "g++ -pthread -B /opt/conda/envs/Python-3.9/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/Python-3.9/include -I/opt/conda/envs/Python-3.9/include -fPIC -O2 -isystem /opt/conda/envs/Python-3.9/include -fPIC -I/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/numpy/core/include -I/opt/conda/envs/Python-3.9/lib/python3.9/site-packages/numpy/core/include -Ibuild/src.linux-x86_64-3.9/numpy/distutils/include -I/opt/conda/envs/Python-3.9/include/python3.9 -c sklearn/cluster/_hierarchical.cpp -o build/temp.linux-x86_64-3.9/sklearn/cluster/_hierarchical.o -MMD -MF build/temp.linux-x86_64-3.9/sklearn/cluster/_hierarchical.o.d -msse -msse2 -msse3" failed with exit status 1
#     INFO:
#     ########### EXT COMPILER OPTIMIZATION ###########
#     INFO: Platform      :
#       Architecture: x64
#       Compiler    : gcc
#
#     CPU baseline  :
#       Requested   : 'min'
#       Enabled     : SSE SSE2 SSE3
#       Flags       : -msse -msse2 -msse3
#       Extra checks: none
#
#     CPU dispatch  :
#       Requested   : 'max -xop -fma4'
#       Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_KNL AVX512_KNM AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#       Generated   : none
#     INFO: CCompilerOpt.cache_flush[857] : write cache to path -> /tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/build/temp.linux-x86_64-3.9/ccompiler_opt_cache_ext.py
#     INFO:
#     ########### CLIB COMPILER OPTIMIZATION ###########
#     INFO: Platform      :
#       Architecture: x64
#       Compiler    : gcc
#
#     CPU baseline  :
#       Requested   : 'min'
#       Enabled     : SSE SSE2 SSE3
#       Flags       : -msse -msse2 -msse3
#       Extra checks: none
#
#     CPU dispatch  :
#       Requested   : 'max -xop -fma4'
#       Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_KNL AVX512_KNM AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#       Generated   : none
#     INFO: CCompilerOpt.cache_flush[857] : write cache to path -> /tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/build/temp.linux-x86_64-3.9/ccompiler_opt_cache_clib.py
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/conda/envs/Python-3.9/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/setup.py'"'"'; __file__='"'"'/tmp/1000810000/pip-install-k8lwgl92/scikit-learn_9fa5ff05397b4aef8ee403222facb6d5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/1000810000/pip-record-4vddskes/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/wsuser/.local/include/python3.9/scikit-learn Check the logs for full command output.
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (1.23.3)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from SciPy) (1.23.3)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-learn>=0.18->lime) (0.17.0)
# Successfully installed ibm-cloud-sdk-core-3.3.4 ibm-watson-openscale-3.0.3 pyJWT-2.0.0
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->ibm_wos_utils) (3.0.4)

# %%
# !pip install --upgrade pyspark==3.2.0 --no-cache | tail -n 1

#If you are running this notebook in non IBM Watson Studio env then uncomment the below pip statements and run it
#!pip install --upgrade pandas==1.2.3 --no-cache | tail -n 1 
#!pip install --upgrade requests==2.23 --no-cache | tail -n 1
#!pip install numpy==1.20.1 --no-cache | tail -n 1
#!pip install SciPy --no-cache | tail -n 1
#!pip install lime --no-cache | tail -n 1

# !pip install --upgrade ibm-watson-machine-learning --user | tail -n 1
# !pip install --upgrade ibm-watson-openscale --no-cache | tail -n 1
# Out:
# Requirement already satisfied: py4j==0.10.9.2 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from pyspark==3.2.0) (0.10.9.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from packaging->ibm-watson-machine-learning) (3.0.4)
# Successfully installed PyJWT-2.4.0 ibm-cloud-sdk-core-3.10.1 ibm-watson-openscale-3.0.23

# %% [markdown]
# ### Action: restart the kernel!

# %% [markdown]
# ## Configure credentials

# %% [markdown]
# - WOS_CREDENTIALS (CP4D)
# - WML_CREDENTIALS (CP4D)
# - DATABASE_CREDENTIALS (DB2 on CP4D or Cloud Object Storage (COS))
# - SCHEMA_NAME

# %%
# After adding each appropriate value, hit enter to add the next value
from IPython.display import clear_output
import os

WOS_CREDENTIALS = {}
WOS_CREDENTIALS["username"] = input("Username : ")
WOS_CREDENTIALS["password"] = input("Password : ")
WOS_CREDENTIALS["url"] = os.environ['RUNTIME_ENV_APSX_URL']

#Clear output to hide sensitive information from being displayed
clear_output(wait=False)

# %%
import json
import requests
import base64
from requests.auth import HTTPBasicAuth
import time
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")

def generate_access_token():
    headers={}
    headers["Accept"] = "application/json"
    auth = HTTPBasicAuth(WOS_CREDENTIALS["username"], WOS_CREDENTIALS["password"])
    
    ICP_TOKEN_URL= WOS_CREDENTIALS["url"] + "/v1/preauth/validateAuth"
    
    response = requests.get(ICP_TOKEN_URL, headers=headers, auth=auth, verify=False)
    json_data = response.json()
    icp_access_token = json_data['accessToken']
    return icp_access_token

token = generate_access_token()

WOS_CREDENTIALS["token"] = token
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'internal-nginx-svc.zen.svc.cluster.local'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
import ibm_watson_openscale
from ibm_cloud_sdk_core.authenticators import CloudPakForDataAuthenticator

DATA_MART_ID = '00000000-0000-0000-0000-000000000000'

#authenticate user
authenticator = CloudPakForDataAuthenticator(
        url=WOS_CREDENTIALS['url'],
        username=WOS_CREDENTIALS['username'],
        password=WOS_CREDENTIALS['password'],
        disable_ssl_verification=True
    )

#connect
wos_client = ibm_watson_openscale.APIClient(authenticator=authenticator, service_url=WOS_CREDENTIALS['url'], service_instance_id=DATA_MART_ID)
print(wos_client.version)
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'internal-nginx-svc.zen.svc.cluster.local'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'internal-nginx-svc.zen.svc.cluster.local'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 3.0.23

# %%
from ibm_watson_machine_learning import APIClient
import os

token = generate_access_token()

wml_credentials = {
   "token": token,
   "instance_id" : "openshift",
   "url": os.environ['RUNTIME_ENV_APSX_URL'],
   "version": "4.5"
}

wml_client = APIClient(wml_credentials)
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'internal-nginx-svc.zen.svc.cluster.local'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# # Training Data

# %%
import pandas as pd
train = pd.read_csv('/project_data/data_asset/train_xgb.csv')
train = train.iloc[: , 1:]
train.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0           6.7          2.5           5.8          1.8  virginica
# 1           5.1          3.7           1.5          0.4     setosa
# 2           5.0          3.2           1.2          0.2     setosa
# 3           7.2          3.0           5.8          1.6  virginica
# 4           5.1          3.8           1.5          0.3     setosa

# %% [markdown]
# # Configure OpenScale <a name="openscale"></a>

# %% [markdown]
# The notebook will now import the necessary libraries and set up a Python OpenScale client.

# %%
from ibm_cloud_sdk_core.authenticators import CloudPakForDataAuthenticator
from ibm_watson_openscale import APIClient

from ibm_watson_openscale import *
from ibm_watson_openscale.supporting_classes.enums import *
from ibm_watson_openscale.supporting_classes import *

# %%
authenticator = CloudPakForDataAuthenticator(
        url=WOS_CREDENTIALS['url'],
        username=WOS_CREDENTIALS['username'],
        password=WOS_CREDENTIALS['password'],
        disable_ssl_verification=True
    )
instance_id='00000000-0000-0000-0000-000000000000' #Datamart id

wos_client = APIClient(service_url=WOS_CREDENTIALS['url'],authenticator=authenticator,service_instance_id = instance_id)
wos_client.version
# Out:
# '3.0.23'

# %% [markdown]
# ## Create datamart

# %% [markdown]
# ### Set up datamart

# %% [markdown]
# Watson OpenScale uses a database to store payload logs and calculated metrics. If database credentials were supplied, the datamart will be created there unless there is an existing datamart and the KEEP_MY_INTERNAL_POSTGRES variable is set to True. If an OpenScale datamart exists in Db2 or PostgreSQL, the existing datamart will be used and no data will be overwritten.
#
# Prior instances of the German Credit model will be removed from OpenScale monitoring.

# %%
wos_client.data_marts.show()
# Out:
# <HTML>
#         <body>
#             <h3>Data Marts</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>description</th><th style='border: 1px solid #dddddd'>internal_database</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>AIOSFASTPATHICP-00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>Data Mart created by OpenScale ExpressPath</td><td style='border: 1px solid #dddddd'>False</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2022-08-08 20:50:24.802000+00:00</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td></tr>
#             </table>
#         </body>
#         </HTML>

# %%
data_marts = wos_client.data_marts.list().result.data_marts
if len(data_marts) == 0:
    if DB_CREDENTIALS is not None:
        if SCHEMA_NAME is None: 
            print("Please specify the SCHEMA_NAME and rerun the cell")

        print('Setting up external datamart')
        added_data_mart_result = wos_client.data_marts.add(
                background_mode=False,
                name="WOS Data Mart",
                description="Data Mart created by WOS tutorial notebook",
                database_configuration=DatabaseConfigurationRequest(
                  database_type=DatabaseType.DB2,
                    credentials=PrimaryStorageCredentialsLong(
                        hostname=DATABASE_CREDENTIALS['hostname'],
                        username=DATABASE_CREDENTIALS['username'],
                        password=DATABASE_CREDENTIALS['password'],
                        db=DATABASE_CREDENTIALS['database'],
                        port=DATABASE_CREDENTIALS['port'],
                        ssl=DATABASE_CREDENTIALS['ssl'],
                        sslmode=DATABASE_CREDENTIALS['sslmode'],
                        certificate_base64=DATABASE_CREDENTIALS['certificate_base64']
                    ),
                    location=LocationSchemaName(
                        schema_name= SCHEMA_NAME
                    )
                )
             ).result
    else:
        print('Setting up internal datamart')
        added_data_mart_result = wos_client.data_marts.add(
                background_mode=False,
                name="WOS Data Mart",
                description="Data Mart created by WOS tutorial notebook", 
                internal_database = True).result
        
    data_mart_id = added_data_mart_result.metadata.id
    
else:
    data_mart_id=data_marts[0].metadata.id
    print('Using existing datamart {}'.format(data_mart_id))
# Out:
# Using existing datamart 00000000-0000-0000-0000-000000000000

# %% [markdown]
# ## Remove existing service provider connected with used WML instance.
# Multiple service providers for the same engine instance are avaiable in Watson OpenScale. To avoid multiple service providers of used WML instance in the tutorial notebook the following code deletes existing service provder(s) and then adds new one.

# %%
SERVICE_PROVIDER_NAME = "WML Function - Regression"
SERVICE_PROVIDER_DESCRIPTION = "WML AI function -  WOS notebook."

# %%
service_providers = wos_client.service_providers.list().result.service_providers
for service_provider in service_providers:
    service_instance_name = service_provider.entity.name
    if service_instance_name == SERVICE_PROVIDER_NAME:
        service_provider_id = service_provider.metadata.id
        wos_client.service_providers.delete(service_provider_id)
        print("Deleted existing service_provider for WML instance: {}".format(service_provider_id))

# %% [markdown]
# ## Add service provider
# Watson OpenScale needs to be bound to the Watson Machine Learning instance to capture payload data into and out of the model.
#
# **Note:** You can bind more than one engine instance if needed by calling `wos_client.service_providers.add` method. Next, you can refer to particular service provider using `service_provider_id`.

# %%
space_id = 'd4c5a38c-44e3-473f-a4ff-c43b3f9cd2d2'
d_id = 'f15b3646-4984-43c9-a9e9-25461dca015e' # deployment id

# %%
added_service_provider_result = wos_client.service_providers.add(
        name=SERVICE_PROVIDER_NAME,
        description=SERVICE_PROVIDER_DESCRIPTION,
        service_type=ServiceTypes.WATSON_MACHINE_LEARNING,
        deployment_space_id = space_id,
        operational_space_id = "production",
        credentials=WMLCredentialsCP4D(
            url=None,
            username=None,
            password=None,
            instance_id=None
        ),
        background_mode=False
    ).result
service_provider_id = added_service_provider_result.metadata.id

# %%
wos_client.service_providers.show()
# Out:
# <HTML>
#         <body>
#             <h3>Service Providers</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>instance_id</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>service_type</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>99999999-9999-9999-9999-999999999999</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>WML Function - Regression</td><td style='border: 1px solid #dddddd'>watson_machine_learning</td><td style='border: 1px solid #dddddd'>2022-09-13 13:38:13.018000+00:00</td><td style='border: 1px solid #dddddd'>e5aac9ed-7953-4a13-ad67-954b7544a774</td></tr><tr><td style='border: 1px solid #dddddd'>99999999-9999-9999-9999-999999999999</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>WML Function</td><td style='border: 1px solid #dddddd'>watson_machine_learning</td><td style='border: 1px solid #dddddd'>2022-09-12 19:52:02.738000+00:00</td><td style='border: 1px solid #dddddd'>68c5c98e-3355-4d7b-90eb-f6a84eb6a07a</td></tr><tr><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>IAE</td><td style='border: 1px solid #dddddd'>custom_machine_learning</td><td style='border: 1px solid #dddddd'>2022-09-11 07:33:58.158000+00:00</td><td style='border: 1px solid #dddddd'>f89f7648-7615-447f-bb75-59e9b3201081</td></tr><tr><td style='border: 1px solid #dddddd'>99999999-9999-9999-9999-999999999999</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>Credit-Risk-WML-Production-ML-Engine_TAI_demo</td><td style='border: 1px solid #dddddd'>watson_machine_learning</td><td style='border: 1px solid #dddddd'>2022-08-25 20:28:18.764000+00:00</td><td style='border: 1px solid #dddddd'>ae922c99-dc81-445c-8743-cd004b0cad37</td></tr><tr><td style='border: 1px solid #dddddd'>99999999-9999-9999-9999-999999999999</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>Credit-Risk-WML-Pre-Production-ML-Engine_TAI_demo</td><td style='border: 1px solid #dddddd'>watson_machine_learning</td><td style='border: 1px solid #dddddd'>2022-08-25 20:15:10.335000+00:00</td><td style='border: 1px solid #dddddd'>b5253aab-f036-4bab-b3ef-becaded6eb38</td></tr><tr><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>Walmart Notebook Batch</td><td style='border: 1px solid #dddddd'>custom_machine_learning</td><td style='border: 1px solid #dddddd'>2022-08-19 06:21:52.192000+00:00</td><td style='border: 1px solid #dddddd'>87624e51-9c77-4b4a-8c3a-931dc7221e76</td></tr><tr><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>Walmart Batch</td><td style='border: 1px solid #dddddd'>custom_machine_learning</td><td style='border: 1px solid #dddddd'>2022-08-10 03:40:22.790000+00:00</td><td style='border: 1px solid #dddddd'>8113053b-6751-4b55-9aca-937cb20a1a31</td></tr><tr><td style='border: 1px solid #dddddd'>99999999-9999-9999-9999-999999999999</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>WOS ExpressPath WML pre_production binding</td><td style='border: 1px solid #dddddd'>watson_machine_learning</td><td style='border: 1px solid #dddddd'>2022-08-08 20:50:47.196000+00:00</td><td style='border: 1px solid #dddddd'>bf0e39f8-d5fc-4728-ad85-7cf1b6dc19b7</td></tr><tr><td style='border: 1px solid #dddddd'>99999999-9999-9999-9999-999999999999</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>WOS ExpressPath WML production binding</td><td style='border: 1px solid #dddddd'>watson_machine_learning</td><td style='border: 1px solid #dddddd'>2022-08-08 20:50:41.616000+00:00</td><td style='border: 1px solid #dddddd'>bb9da7e5-88e6-405e-800b-bead653da540</td></tr>
#             </table>
#         </body>
#         </HTML>

# %%
asset_deployment_details = wos_client.service_providers.list_assets(data_mart_id=data_mart_id, service_provider_id=service_provider_id,deployment_id=d_id, deployment_space_id = space_id).result['resources'][0]
asset_deployment_details
# Out:
# {'metadata': {'guid': 'f15b3646-4984-43c9-a9e9-25461dca015e',
#   'created_at': '2022-09-12T23:30:02.783Z',
#   'modified_at': '2022-09-12T23:30:02.783Z'},
#  'entity': {'name': 'iris reg 0912',
#   'type': 'online',
#   'scoring_endpoint': {'url': 'https://ibm-nginx-svc.zen.svc.cluster.local/ml/v4/deployments/f15b3646-4984-43c9-a9e9-25461dca015e/predictions'},
#   'asset': {},
#   'asset_properties': {}}}

# %%
model_asset_details_from_deployment=wos_client.service_providers.get_deployment_asset(data_mart_id=data_mart_id,service_provider_id=service_provider_id,deployment_id=d_id,deployment_space_id=space_id)
model_asset_details_from_deployment
# Out:
# {'metadata': {'guid': 'f15b3646-4984-43c9-a9e9-25461dca015e',
#   'created_at': '2022-09-12T23:30:02.783Z',
#   'modified_at': '2022-09-12T23:30:02.783Z'},
#  'entity': {'name': 'iris reg 0912',
#   'type': 'online',
#   'scoring_endpoint': {'url': 'https://ibm-nginx-svc.zen.svc.cluster.local/ml/v4/deployments/f15b3646-4984-43c9-a9e9-25461dca015e/predictions'},
#   'asset': {'asset_id': 'efaf0bfa-d31d-4e70-aeb3-49093272b681',
#    'url': 'https://ibm-nginx-svc.zen.svc.cluster.local/ml/v4/functions/efaf0bfa-d31d-4e70-aeb3-49093272b681?space_id=d4c5a38c-44e3-473f-a4ff-c43b3f9cd2d2&version=2020-06-12',
#    'name': 'iris reg 0912',
#    'asset_type': 'function',
#    'created_at': '2022-09-12T23:30:01.702Z',
#    'modified_at': '2022-09-12T23:30:02.210Z'},
#   'asset_properties': {'model_type': 'python',
#    'runtime_environment': 'python-3.9'}}}

# %% [markdown]
# ## Subscriptions

# %%
wos_client.subscriptions.show()
# Out:
# <HTML>
#         <body>
#             <h3>Subscriptions</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>asset_id</th><th style='border: 1px solid #dddddd'>asset_name</th><th style='border: 1px solid #dddddd'>data_mart_id</th><th style='border: 1px solid #dddddd'>deployment_id</th><th style='border: 1px solid #dddddd'>deployment_name</th><th style='border: 1px solid #dddddd'>service_provider_id</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>8bbce45d-9d0f-4998-994d-ba94af5ba00f</td><td style='border: 1px solid #dddddd'>walmartAutomation3</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>8e6db881-0e8c-460b-b631-3d28c0319fca</td><td style='border: 1px solid #dddddd'>walmartAutomation3</td><td style='border: 1px solid #dddddd'>f89f7648-7615-447f-bb75-59e9b3201081</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2022-09-13 02:11:58.822000+00:00</td><td style='border: 1px solid #dddddd'>7bb1d0d5-a083-4c2b-beeb-2bd15b0d89e2</td></tr><tr><td style='border: 1px solid #dddddd'>29a8d393-623c-4d6e-98ce-a4f55416583d</td><td style='border: 1px solid #dddddd'>WALMARTAUTOMATION_AS</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>ed456f0e-19bb-4fd2-bd10-20be3cad755d</td><td style='border: 1px solid #dddddd'>WALMARTAUTOMATION_AS</td><td style='border: 1px solid #dddddd'>87624e51-9c77-4b4a-8c3a-931dc7221e76</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2022-09-13 00:51:06.626000+00:00</td><td style='border: 1px solid #dddddd'>cc3f9134-1337-42d3-8b7d-06195ead425f</td></tr><tr><td style='border: 1px solid #dddddd'>851cdca3-d474-4251-b25c-866483e7689e</td><td style='border: 1px solid #dddddd'>iris class 0912</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>bf6bbfce-250f-4101-be63-63fa469d5131</td><td style='border: 1px solid #dddddd'>iris class 0912</td><td style='border: 1px solid #dddddd'>68c5c98e-3355-4d7b-90eb-f6a84eb6a07a</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2022-09-12 19:55:43.266000+00:00</td><td style='border: 1px solid #dddddd'>2dd86d22-d9fe-47e7-9de1-442b640ac58d</td></tr><tr><td style='border: 1px solid #dddddd'>fe535d57-32dd-4b14-8958-a5977e7e9860</td><td style='border: 1px solid #dddddd'>walmartAutomation2</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>831cae89-fc1b-4d70-b9b7-e067b690ca94</td><td style='border: 1px solid #dddddd'>walmartAutomation2</td><td style='border: 1px solid #dddddd'>f89f7648-7615-447f-bb75-59e9b3201081</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2022-09-12 05:07:29.502000+00:00</td><td style='border: 1px solid #dddddd'>6da441c0-164a-4d33-a06d-c8ed0a52b453</td></tr><tr><td style='border: 1px solid #dddddd'>ad60e39b-9c69-41fe-b092-d5033a0923f3</td><td style='border: 1px solid #dddddd'>walmartAutomation</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>21718f09-1c8f-40ed-b4d9-a678c7423dce</td><td style='border: 1px solid #dddddd'>walmartAutomation</td><td style='border: 1px solid #dddddd'>f89f7648-7615-447f-bb75-59e9b3201081</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2022-09-11 21:26:31.034000+00:00</td><td style='border: 1px solid #dddddd'>57edd725-bfc3-4f9f-9e5e-b3ba0214838b</td></tr><tr><td style='border: 1px solid #dddddd'>b376cd17-407f-477f-a649-ecc9003025a6</td><td style='border: 1px solid #dddddd'>XGB - Credit Risk Pipeline_TAI_demo</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>9ffcb318-420a-4fb4-9ab8-a84be5f8ff41</td><td style='border: 1px solid #dddddd'>prod_xgb_credit_risk_pipeline_deployment_TAI_demo</td><td style='border: 1px solid #dddddd'>ae922c99-dc81-445c-8743-cd004b0cad37</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2022-08-25 20:33:08.565000+00:00</td><td style='border: 1px solid #dddddd'>3ae086ec-53f2-413b-90d9-b86577370aa9</td></tr><tr><td style='border: 1px solid #dddddd ...
#             </table>
#         </body>
#         </HTML>
# Note: First 10 records were displayed.

# %%
subscriptions = wos_client.subscriptions.list().result.subscriptions
for subscription in subscriptions:
    sub_model_id = subscription.entity.asset.asset_id
    if sub_model_id == d_id:
        wos_client.subscriptions.delete(subscription.metadata.id)
        print('Deleted existing subscription for model', sub_model_id)

# %% [markdown]
# This code creates the model subscription in OpenScale using the Python client API. Note that we need to provide the model unique identifier, and some information about the model itself.

# %%
from ibm_watson_openscale.base_classes.watson_open_scale_v2 import Asset, AssetDeploymentRequest, AssetPropertiesRequest, Target, SparkStruct

training = {'id': 'training schema', 'type': 'struct', 'fields': [
    {'name': 'Sepal.Length', 'type': 'double', 'nullable': False, 'metadata': {}},
    {'name': 'Sepal.Width', 'type': 'double', 'nullable': False, 'metadata': {}},
    {'name': 'Petal.Length', 'type': 'double', 'nullable': False, 'metadata': {}},
    {'name': 'Petal.Width', 'type': 'double', 'nullable': False, 'metadata': {}},
    {'name': 'Species', 'type': 'string', 'nullable': False, 'metadata': {}}]}

subscription_details = wos_client.subscriptions.add(
        data_mart_id=data_mart_id,
        service_provider_id=service_provider_id,
        asset=Asset(
            asset_id=model_asset_details_from_deployment["entity"]["asset"]["asset_id"],
            name=model_asset_details_from_deployment["entity"]["asset"]["name"],
            url=model_asset_details_from_deployment["entity"]["asset"]["url"],
            asset_type=AssetTypes.MODEL,
            input_data_type=InputDataType.STRUCTURED,
            problem_type=ProblemType.REGRESSION
        ),
        deployment=AssetDeploymentRequest(
            deployment_id=asset_deployment_details['metadata']['guid'],
            name=asset_deployment_details['entity']['name'],
            deployment_type= DeploymentTypes.ONLINE,
            url=asset_deployment_details['entity']['scoring_endpoint']['url']
        ),
        asset_properties=AssetPropertiesRequest(
            label_column='Sepal.Length',
            prediction_field='prediction',
            feature_fields = ["Species","Sepal.Width","Petal.Length","Petal.Width"],
            categorical_fields = ["Species"],
            training_data_reference=TrainingDataReference(type='cos',
                                                          location=COSTrainingDataReferenceLocation(bucket = 'cs-xgb-bucket',
                                                                                                    file_name = 'train_xgb.csv'),
                                                          connection=COSTrainingDataReferenceConnection.from_dict({
                                                                        "resource_instance_id": 'crn:v1:bluemix:public:cloud-object-storage:global:a/677fc976cf4b442c912b1e7bfecf48db:ac0f6349-84a7-4d6f-8b1b-41c0ddb480f4::',
                                                                        "url": "https://control.cloud-object-storage.cloud.ibm.com/v2/endpoints",
                                                                        "api_key": 'YP0KB91UMMIWzKhER4ZAt0eB_6dnD6XBngJ4Sw2SjL9v',
                                                                        "iam_url": "https://iam.ng.bluemix.net/oidc/token"})),
            training_data_schema=SparkStruct.from_dict(training)
        ),
        background_mode=False
    ).result
subscription_id = subscription_details.metadata.id
subscription_id
# Out:
# =============================================================================
#
#  Waiting for end of adding subscription 6c75ac44-0504-47e6-9c38-f9b5630a4655
#
# =============================================================================
#
#
#
# preparing
# active
#
# -------------------------------------------
#  Successfully finished adding subscription
# -------------------------------------------
# '6c75ac44-0504-47e6-9c38-f9b5630a4655'

# %% [markdown]
# ## Gather Training Statistics
#
# In order to set up some of the OpenScale monitors (explainability and fairness) we will need training statistics describing our training data. In this step, we load the data used for training and compute these statistics, to be used in the following section.
#
# To get training statistics, we could either point to training data stored in Db2 or Cloud Object Storage (not covered here, see this section of the documentation, or, load the dataset as a pandas dataset and use the TrainingStats class. Therefore, we first load the training dataset, and then pass it to TrainingStats along with some parameters:

# %%
fairness_parameters = {
    'fairness_attributes': [
        {'feature': 'Petal.Length',
         "majority": [[1.0,3.0]],
         "threshold": 0.8,
         "minority": [[4.0,5.0]]
        }
    ],
    "favourable_class": [[1.0,2.0]],
    "unfavourable_class": [[3.0,4.0]],
    "min_records": 10
}

training_parameters = {
    'label_column': "Sepal.Length",
    'feature_columns': ['Species', 'Sepal.Width', 'Petal.Length', 'Petal.Width'],
    'categorical_columns': ["Species"],
    'fairness_inputs': fairness_parameters,
    'problem_type': 'regression'
}

# %%
from ibm_watson_openscale.utils.training_stats import TrainingStats

training_stats = TrainingStats(train, training_parameters, explain=True, fairness=True, drop_na=True)
# Out:
# Requirement already satisfied: ibm-wos-utils in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (4.5.20)
# Requirement already satisfied: retrying==1.3.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (1.3.3)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (1.23.3)
# Requirement already satisfied: more-itertools>=8.6.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (8.14.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (2.26.0)
# Requirement already satisfied: ibm-db in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (3.1.0)
# Requirement already satisfied: scikit-learn==1.0.2 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (1.0.2)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (1.3.4)
# Requirement already satisfied: jenkspy in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (0.3.1)
# Requirement already satisfied: scikit-image in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (0.18.3)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (4.62.3)
# Requirement already satisfied: nltk in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wos-utils) (3.7)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from retrying==1.3.3->ibm-wos-utils) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-learn==1.0.2->ibm-wos-utils) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-learn==1.0.2->ibm-wos-utils) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-learn==1.0.2->ibm-wos-utils) (1.9.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk->ibm-wos-utils) (2021.11.2)
# Requirement already satisfied: click in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from nltk->ibm-wos-utils) (8.0.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from pandas->ibm-wos-utils) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from pandas->ibm-wos-utils) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->ibm-wos-utils) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->ibm-wos-utils) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->ibm-wos-utils) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->ibm-wos-utils) (2.0.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-image->ibm-wos-utils) (3.5.0)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-image->ibm-wos-utils) (2.6.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-image->ibm-wos-utils) (9.0.1)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-image->ibm-wos-utils) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-image->ibm-wos-utils) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scikit-image->ibm-wos-utils) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->ibm-wos-utils) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->ibm-wos-utils) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->ibm-wos-utils) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->ibm-wos-utils) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->ibm-wos-utils) (0.11.0)

# %%
training_stats

# %%
# did not work
#training_stats_json = training_stats.get_training_statistics()

# %% [markdown]
# # Drift

# %% [markdown]
# ## Run Drift Trainer
#
# In order to monitor for Drift, OpenScale needs to train a Drift Model that learns the data used for training along with the predictions. It's important to perform this step before setting up payload logging: when we train the Drift model, we will be making some scoring requests to the deployment and we want to avoid logging those, as they are not "real" scoring requests coming from end users. Therefore we make sure to perform this step before the next section (payload logging setup).

# %%
from ibm_wos_utils.drift.drift_trainer import DriftTrainer

# %%
def score(data, d_id=d_id):
    import numpy as np
    """
    From the generate_drift_detection_model docs:
    A function that accepts a dataframe with features as columns and returns a tuple of numpy array
    of probabilities array of shape `(n_samples,n_classes)` and numpy array of prediction vector of shape `(n_samples,)`
    """
    feature_columns = ["Species","Sepal.Width","Petal.Length","Petal.Width"]
    scoring_payload = {'input_data': [{'features': feature_columns, 'values': data[feature_columns].values.tolist()}]}
    scoring_result = wml_client.deployments.score(d_id, scoring_payload)
    
    preds = np.array([x[0] for x in scoring_result['predictions'][0]['values']])
    return preds

# %%
wml_client.set.default_space(space_id)
# Out:
# 'SUCCESS'

# %%
drift_inputs = {
    'feature_columns': ["Species","Sepal.Width","Petal.Length","Petal.Width"],
    'categorical_columns': ["Species"],
    'label_column': 'Sepal.Length',
    'problem_type': 'regression'
    
}

drift_trainer = DriftTrainer(train, drift_inputs)
drift_trainer.generate_drift_detection_model(score, batch_size=train.shape[0])
drift_trainer.learn_constraints()
drift_trainer.create_archive()
# Out:
# Computing feature stats...: 100%|██████████| 4/4 [00:00<00:00, 133.61features/s]
# Learning single feature constraints...: 100%|██████████| 5/5 [00:00<00:00, 265.78constraints/s]
# Learning two feature constraints...: 100%|██████████| 9/9 [00:00<00:00, 22.41constraints/s]

# %%
#check if drift model has been saved
# !ls
# Out:
# config.yaml  drift_detection_model.tar.gz

# %%
upload_response = wos_client.monitor_instances.upload_drift_model(
    model_path="./drift_detection_model.tar.gz",
    data_mart_id=DATA_MART_ID,
    subscription_id=subscription_id
)

if upload_response.get_status_code() == 200:
    print('Successfully uploaded the drift model.')
else:
    print('Something went wrong. Look into this error before running the next section.')
    print('Hint: check that sklearn is in v. 0.20.2 (restart your kernel, make sure to run section 0.2).')
# Out:
# Successfully uploaded the drift model.

# %%
#remove the locally saved drift model
# !mv drift_detection_model.tar.gz "/project_data/data_asset"

# %%
# check if the locally saved drift model is deleted
# !ls
# Out:
# config.yaml

# %% [markdown]
# ## Upload this file to configure drift!

# %% [markdown]
# # Payload Logging

# %%
import time

time.sleep(5)
payload_data_set_id = None
payload_data_set_id = wos_client.data_sets.list(type=DataSetTypes.PAYLOAD_LOGGING, 
                                                target_target_id=subscription_id, 
                                                target_target_type=TargetTypes.SUBSCRIPTION).result.data_sets[0].metadata.id
if payload_data_set_id is None:
    print("Payload data set not found. Please check subscription status.")
else:
    print("Payload data set id: ", payload_data_set_id)
# Out:
# Payload data set id:  697493b8-7315-45d1-9286-da9cb6b326ab

# %%
wos_client.data_sets.show()
# Out:
# <HTML>
#         <body>
#             <h3>Data sets</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>data_mart_id</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>target_id</th><th style='border: 1px solid #dddddd'>target_type</th><th style='border: 1px solid #dddddd'>type</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>6c75ac44-0504-47e6-9c38-f9b5630a4655</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>payload_logging_error</td><td style='border: 1px solid #dddddd'>2022-09-13 13:42:20.668000+00:00</td><td style='border: 1px solid #dddddd'>effc8ece-7817-458d-a43f-f54b69fdd5d3</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>6c75ac44-0504-47e6-9c38-f9b5630a4655</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>manual_labeling</td><td style='border: 1px solid #dddddd'>2022-09-13 13:42:20.552000+00:00</td><td style='border: 1px solid #dddddd'>65344352-9eed-4fe6-8fd6-f8847a7bf346</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>6c75ac44-0504-47e6-9c38-f9b5630a4655</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>payload_logging</td><td style='border: 1px solid #dddddd'>2022-09-13 13:42:20.438000+00:00</td><td style='border: 1px solid #dddddd'>697493b8-7315-45d1-9286-da9cb6b326ab</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>3ae086ec-53f2-413b-90d9-b86577370aa9</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>manual_labeling</td><td style='border: 1px solid #dddddd'>2022-08-25 20:33:16.886000+00:00</td><td style='border: 1px solid #dddddd'>18293fc2-fa41-4ddf-81e3-88d6a0ee9c61</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>3ae086ec-53f2-413b-90d9-b86577370aa9</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>feedback</td><td style='border: 1px solid #dddddd'>2022-08-25 20:37:42.851000+00:00</td><td style='border: 1px solid #dddddd'>6e0bbbd4-16d7-459a-9d99-73b9ee78e777</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>7bb1d0d5-a083-4c2b-beeb-2bd15b0d89e2</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>payload_logging_error</td><td style='border: 1px solid #dddddd'>2022-09-13 02:12:08.670000+00:00</td><td style='border: 1px solid #dddddd'>99277d96-595f-4d2d-a9c6-291678af8960</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>7bb1d0d5-a083-4c2b-beeb-2bd15b0d89e2</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>training</td><td style='border: 1px solid #dddddd'>2022-09-13 02:12:08.348000+00:00</td><td style='border: 1px solid #dddddd'>0e57a881-ebeb-4a72-92f4-cf832c975157</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>7bb1d0d5-a083-4c2b-beeb-2bd15b0d89e2</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>manual_labeling</td><td style='border: 1px solid #dddddd'>2022-09-13 02:12:08.032000+00:00</td><td style='border: 1px solid #dddddd'>68ff3bc0-39db-4078-b7b9-35752aa286bc</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>a ...
#             </table>
#         </body>
#         </HTML>
# Note: First 10 records were displayed.

# %% [markdown]
# ### Score the model so we can configure monitors

# %% [markdown]
# Now that the WML service has been bound and the subscription has been created, we need to send a request to the model before we configure OpenScale. This allows OpenScale to create a payload log in the datamart with the correct schema, so it can capture data coming into and out of the model.

# %%
fields = ["Sepal.Length","Sepal.Width","Petal.Length","Petal.Width", "Species"]

payload_scoring = { "input_data": [ {"fields": fields,"values": json.loads(train.iloc[: ,].to_json(orient="values"))}]}
scoring_response = wml_client.deployments.score(d_id, payload_scoring)
#scoring_response

# %% [markdown]
# ## Check if WML payload logging worked else manually store payload records

# %%
import uuid
from ibm_watson_openscale.supporting_classes.payload_record import PayloadRecord
time.sleep(5)
pl_records_count = wos_client.data_sets.get_records_count(payload_data_set_id)
print("Number of records in the payload logging table: {}".format(pl_records_count))
if pl_records_count == 0:
    print("Payload logging did not happen, performing explicit payload logging.")
    wos_client.data_sets.store_records(data_set_id=payload_data_set_id, request_body=[PayloadRecord(
                   scoring_id=str(uuid.uuid4()),
                   request=payload_scoring["input_data"][0],
                   response={"fields": scoring_response['predictions'][0]['fields'], "values":scoring_response['predictions'][0]['values']},
                   response_time=460
               )])
    time.sleep(20)
    pl_records_count = wos_client.data_sets.get_records_count(payload_data_set_id)
    print("Number of records in the payload logging table: {}".format(pl_records_count))
# Out:
# Number of records in the payload logging table: 112

# %% [markdown]
# # Quality monitoring and feedback logging <a name="quality"></a>

# %% [markdown]
# ## Enable quality monitoring

# %% [markdown]
# The code below waits ten seconds to allow the payload logging table to be set up before it begins enabling monitors. First, it turns on the quality (accuracy) monitor and sets an alert threshold of 70%. OpenScale will show an alert on the dashboard if the model accuracy measurement (area under the curve, in the case of a binary classifier) falls below this threshold.
#
# The second paramater supplied, min_records, specifies the minimum number of feedback records OpenScale needs before it calculates a new measurement. The quality monitor runs hourly, but the accuracy reading in the dashboard will not change until an additional 50 feedback records have been added, via the user interface, the Python client, or the supplied feedback endpoint.

# %%
import time

time.sleep(10)
target = Target(
        target_type=TargetTypes.SUBSCRIPTION,
        target_id=subscription_id
)
parameters = {
    "min_feedback_data_size": 10
}
quality_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.QUALITY.ID,
    target=target,
    parameters=parameters
).result
# Out:
# ===================================================================================
#
#  Waiting for end of monitor instance creation ed151cca-fc8a-4ccf-b398-325f212a4088
#
# ===================================================================================
#
#
#
# active
#
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------

# %%
quality_monitor_instance_id = quality_monitor_details.metadata.id
quality_monitor_instance_id
# Out:
# 'ed151cca-fc8a-4ccf-b398-325f212a4088'

# %% [markdown]
# ## Feedback logging

# %%
feedback_dataset_id = None
feedback_dataset = wos_client.data_sets.list(type=DataSetTypes.FEEDBACK, 
                                                target_target_id=subscription_id, 
                                                target_target_type=TargetTypes.SUBSCRIPTION).result
print(feedback_dataset)
feedback_dataset_id = feedback_dataset.data_sets[0].metadata.id
if feedback_dataset_id is None:
    print("Feedback data set not found. Please check quality monitor status.")
# Out:
# {
#   "data_sets": [
#     {
#       "metadata": {
#         "id": "b6c81a87-6e4e-4b8e-a82f-9c78d39e273a",
#         "crn": "crn:v1:bluemix:public:aiopenscale:us-south:a/na:00000000-0000-0000-0000-000000000000:data_set:b6c81a87-6e4e-4b8e-a82f-9c78d39e273a",
#         "url": "/v2/data_sets/b6c81a87-6e4e-4b8e-a82f-9c78d39e273a",
#         "created_at": "2022-09-13T13:49:33.679000Z",
#         "created_by": "internal-service",
#         "modified_at": "2022-09-13T13:49:36.638000Z",
#         "modified_by": "internal-service"
#       },
#       "entity": {
#         "data_mart_id": "00000000-0000-0000-0000-000000000000",
#         "name": "6c75ac44-0504-47e6-9c38-f9b5630a4655_feedback",
#         "description": "6c75ac44-0504-47e6-9c38-f9b5630a4655_feedback",
#         "type": "feedback",
#         "target": {
#           "target_type": "subscription",
#           "target_id": "6c75ac44-0504-47e6-9c38-f9b5630a4655"
#         },
#         "schema_update_mode": "auto",
#         "data_schema": {
#           "type": "struct",
#           "fields": [
#             {
#               "metadata": {
#                 "modeling_role": "target"
#               },
#               "name": "Sepal.Length",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {
#                 "modeling_role": "feature"
#               },
#               "name": "Sepal.Width",
#               "nullable": false,
#               "type": "double"
#             },
#             {
#               "metadata": {
#                 "modeling_role": "feature"
#               },
#               "name": "Petal.Length",
#               "nullable": false,
#               "type": "double"
#             },
#             {
#               "metadata": {
#                 "modeling_role": "feature"
#               },
#               "name": "Petal.Width",
#               "nullable": false,
#               "type": "double"
#             },
#             {
#               "metadata": {
#                 "columnInfo": {
#                   "columnLength": 64
#                 },
#                 "measure": "discrete",
#                 "modeling_role": "feature"
#               },
#               "name": "Species",
#               "nullable": false,
#               "type": "string"
#             },
#             {
#               "metadata": {
#                 "columnInfo": {
#                   "columnLength": 128
#                 },
#                 "modeling_role": "record-id",
#                 "primary_key": true
#               },
#               "name": "record_id",
#               "nullable": false,
#               "type": "string"
#             },
#             {
#               "metadata": {
#                 "modeling_role": "record-timestamp"
#               },
#               "name": "record_timestamp",
#               "nullable": false,
#               "type": "timestamp"
#             },
#             {
#               "metadata": {
#                 "transaction_id_key": true
#               },
#               "name": "transaction_id",
#               "nullable": true,
#               "type": "string"
#             },
#             {
#               "metadata": {},
#               "name": "_original_prediction",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "_original_probability",
#               "nullable": true,
#               "type": {
#                 "containsNull": true,
#                 "elementType": "double",
#                 "type": "array"
#               }
#             },
#             {
#               "metadata": {},
#               "name": "_debiased_prediction",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "_debiased_probability",
#               "nullable": true,
#               "type": {
#                 "containsNull": true,
#                 "elementType": "double",
#                 "type": "array"
#               }
#             }
#           ]
#         },
#         "location": {
#           "table_name": "AIOSFASTPATHICP-00000000-0000-0000-0000-000000000000.Feedback_6c75ac44-0504-47e6-9c38-f9b5630a4655"
#         },
#         "status": {
#           "state": "active"
#         }
#       }
#     }
#   ]
# }

# %%
#wos_client.data_sets.store_records(feedback_dataset_id, request_body=feedback_data, background_mode=False)

#wos_client.data_sets.get_records_count(data_set_id=feedback_dataset_id)

#run_details = wos_client.monitor_instances.run(monitor_instance_id=quality_monitor_instance_id, background_mode=False).result

#wos_client.monitor_instances.show_metrics(monitor_instance_id=quality_monitor_instance_id)

# need to look into this

# %% [markdown]
# ## Look into feedback!

# %% [markdown]
# # Fairness, drift monitoring and explanations
#  <a name="fairness"></a>

# %% [markdown]
# The code below configures fairness monitoring for our model. It turns on monitoring for two features, Sex and Age. In each case, we must specify:
#   * Which model feature to monitor
#   * One or more **majority** groups, which are values of that feature that we expect to receive a higher percentage of favorable outcomes
#   * One or more **minority** groups, which are values of that feature that we expect to receive a higher percentage of unfavorable outcomes
#   * The threshold at which we would like OpenScale to display an alert if the fairness measurement falls below (in this case, 95%)
#
# Additionally, we must specify which outcomes from the model are favourable outcomes, and which are unfavourable. We must also provide the number of records OpenScale will use to calculate the fairness score. In this case, OpenScale's fairness monitor will run hourly, but will not calculate a new fairness rating until at least 200 records have been added. Finally, to calculate fairness, OpenScale must perform some calculations on the training data, so we provide the dataframe containing the data.

# %%
wos_client.monitor_instances.show()
# Out:
# <HTML>
#         <body>
#             <h3>Monitor instances</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>data_mart_id</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>target_id</th><th style='border: 1px solid #dddddd'>target_type</th><th style='border: 1px solid #dddddd'>monitor_definition_id</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>6c75ac44-0504-47e6-9c38-f9b5630a4655</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>quality</td><td style='border: 1px solid #dddddd'>2022-09-13 13:49:33.102000+00:00</td><td style='border: 1px solid #dddddd'>ed151cca-fc8a-4ccf-b398-325f212a4088</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>3ae086ec-53f2-413b-90d9-b86577370aa9</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>statistical_parity_differences</td><td style='border: 1px solid #dddddd'>2022-08-30 20:54:32.848000+00:00</td><td style='border: 1px solid #dddddd'>1e752fbc-5140-4ddd-84ef-aa98958ce430</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>3ae086ec-53f2-413b-90d9-b86577370aa9</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>fairness</td><td style='border: 1px solid #dddddd'>2022-08-25 20:39:33.117000+00:00</td><td style='border: 1px solid #dddddd'>07306eb9-dede-4f42-a705-318f90182320</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2dd86d22-d9fe-47e7-9de1-442b640ac58d</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>fairness</td><td style='border: 1px solid #dddddd'>2022-09-12 20:04:52.545000+00:00</td><td style='border: 1px solid #dddddd'>7003b7c7-7152-4ad0-bdce-4ea4081ff9eb</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>b2ef444f-1bad-4464-926f-ab9a1a25992b</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>fairness</td><td style='border: 1px solid #dddddd'>2022-08-08 20:59:26.313000+00:00</td><td style='border: 1px solid #dddddd'>5c669fbb-c4b2-4fc7-b155-feb0071ce8d8</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>b2ef444f-1bad-4464-926f-ab9a1a25992b</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>drift</td><td style='border: 1px solid #dddddd'>2022-08-08 20:59:39.881000+00:00</td><td style='border: 1px solid #dddddd'>e0181aa1-d394-463b-b502-60f546b3b57f</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>3ae086ec-53f2-413b-90d9-b86577370aa9</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>drift</td><td style='border: 1px solid #dddddd'>2022-08-25 20:43:14.566000+00:00</td><td style='border: 1px solid #dddddd'>f70a59c1-707e-4ece-bcee-06566c6389fa</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2dd86d22-d9fe-47e7-9de1-442b640ac58d</td><td style='border: 1px solid #dddddd'>subscription</td><td style='border: 1px solid #dddddd'>drift</td><td style='border: 1px solid #dddddd'>2022-09-12 20:04:07.244000+00:00</td><td style='border: 1px solid #dddddd'>b7526797-b323-46e9-b494-16561a157a61</td></tr><tr><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-000000000000</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dd ...
#             </table>
#         </body>
#         </HTML>
# Note: First 10 records were displayed.

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id

)
parameters = {
    "features": [
       {
                "feature": "Petal.Length",
                "majority": [[1,3]],
                "threshold": 0.8,
                "minority": [[4,5]]
            }
    ],
    "favourable_class": [[1,2]],
    "unfavourable_class": [[3,4]],
    "min_records": 10
}

fairness_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.FAIRNESS.ID,
    target=target,
    parameters=parameters).result
fairness_monitor_instance_id =fairness_monitor_details.metadata.id
fairness_monitor_instance_id
# Out:
# ===================================================================================
#
#  Waiting for end of monitor instance creation 5e3ad3ac-b9af-427b-bfe1-51d090423692
#
# ===================================================================================
#
#
#
# active
#
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------
# '5e3ad3ac-b9af-427b-bfe1-51d090423692'

# %% [markdown]
# ## Drift configuration

# %% [markdown]
# This did not work! BUT we can upload our drift monitor...

# %%
monitor_instances = wos_client.monitor_instances.list().result.monitor_instances
for monitor_instance in monitor_instances:
    monitor_def_id=monitor_instance.entity.monitor_definition_id
    if monitor_def_id == "drift" and monitor_instance.entity.target.target_id == subscription_id:
        wos_client.monitor_instances.delete(monitor_instance.metadata.id)
        print('Deleted existing drift monitor instance with id: ', monitor_instance.metadata.id)

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id

)
parameters = {
    "min_samples": 10,
    "drift_threshold": 0.1,
    "train_drift_model": True,
    "enable_model_drift": True,
    "enable_data_drift": True
}

drift_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.DRIFT.ID,
    target=target,
    parameters=parameters
).result

drift_monitor_instance_id = drift_monitor_details.metadata.id
drift_monitor_instance_id
# Out:
# ===================================================================================
#
#  Waiting for end of monitor instance creation 4223d98b-da0a-4355-bb3e-e1240260fe11
#
# ===================================================================================
#
#
#
# error
#
# -----------------------------------------------------
#  Monitor instance creation failed with status: error
# -----------------------------------------------------
#
#
# Reason: ['code: AIQDD6004E, message: Unable to read the train_xgb.csv training data file in the cs-xgb-bucket COS bucket.']
# '4223d98b-da0a-4355-bb3e-e1240260fe11'

# %% [markdown]
# ## Score the model again now that monitoring is configured

# %% [markdown]
# This next section randomly selects 200 records from the data feed and sends those records to the model for predictions. This is enough to exceed the minimum threshold for records set in the previous section, which allows OpenScale to begin calculating fairness.

# %%
import pandas as pd
iris = pd.read_csv('/project_data/data_asset/iris.csv')
iris = iris.iloc[: , 1:]
iris.head()

# %%
sample = iris.sample(n=100)

# %% [markdown]
# Score 200 randomly chosen records

# %%
payload_scoring = {"input_data": [{"fields": ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species'], "values": json.loads(sample.iloc[: ,].to_json(orient="values"))}]}
#payload_scoring

# %%
scoring_response = wml_client.deployments.score(d_id, payload_scoring)
time.sleep(5)

if pl_records_count == 8:
    print("Payload logging did not happen, performing explicit payload logging.")
    wos_client.data_sets.store_records(data_set_id=payload_data_set_id, request_body=[PayloadRecord(
                   scoring_id=str(uuid.uuid4()),
                   request=payload_scoring,
                   response=scoring_response,
                   response_time=460
               )])
    time.sleep(5)
    pl_records_count = wos_client.data_sets.get_records_count(payload_data_set_id)
    print("Number of records in the payload logging table: {}".format(pl_records_count))

# %%
print('Number of records in payload table: ', wos_client.data_sets.get_records_count(data_set_id=payload_data_set_id))
# Out:
# Number of records in payload table:  212

# %% [markdown]
# ## Run fairness monitor

# %% [markdown]
# Kick off a fairness monitor run on current data. The monitor runs hourly, but can be manually initiated using the Python client, the REST API, or the graphical user interface.

# %%
time.sleep(5)
run_details = wos_client.monitor_instances.run(monitor_instance_id=fairness_monitor_instance_id, background_mode=False)
# Out:
# ========================================================================
#
#  Waiting for end of monitoring run f0eea197-8cda-4876-9dff-095bc51ddca6
#
# ========================================================================
#
#
#
# running.............................
# error
#
# -------------------------------
#  Run failed with status: error
# -------------------------------
#
#
# Reason: ["code: AIQFM6004, message: An unexpected bias error occured. An error while doing the scoring for the datamart 00000000-0000-0000-0000-000000000000, deployment_id f15b3646-4984-43c9-a9e9-25461dca015e and subscription_id 6c75ac44-0504-47e6-9c38-f9b5630a4655. Error: HTTPSConnectionPool(host='aiopenscale-ibm-aios-nginx-internal.zen.svc.cluster.local', port=443): Read timed out. (read timeout=150)."]

# %%
time.sleep(10)
wos_client.monitor_instances.show_metrics(monitor_instance_id=fairness_monitor_instance_id)

# %% [markdown]
# ## Run drift monitor

# %% [markdown]
# Kick off a drift monitor run on current data. The monitor runs every hour, but can be manually initiated using the Python client, the REST API.

# %%
drift_run_details = wos_client.monitor_instances.run(monitor_instance_id=drift_monitor_instance_id, background_mode=False)

# %%
time.sleep(5)
wos_client.monitor_instances.show_metrics(monitor_instance_id=drift_monitor_instance_id)

# %% [markdown]
# ## Configure Explainability

# %% [markdown]
# Finally, we provide OpenScale with the training data to enable and configure the explainability features.

# %%
parameters = {
    "enabled": True,
    "training_statistics": training_stats_json["explainability_configuration"]
}

explainability_details = wos_client.monitor_instances.create(
    data_mart_id=DATA_MART_ID,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.EXPLAINABILITY.ID,
    target=target_subscription,
    parameters=parameters
)

if explainability_details.status_code == 200:
    explainability_monitor_id = explainability_details.result.metadata.id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/1000810000/ipykernel_1780/2003344846.py in <module>
#       1 parameters = {
#       2     "enabled": True,
# ----> 3     "training_statistics": training_stats_json["explainability_configuration"]
#       4 }
#       5
#
# NameError: name 'training_stats_json' is not defined

# %% [markdown]
# ## Run explanation for sample record

# %%
pl_records_resp = wos_client.data_sets.get_list_of_records(data_set_id=payload_data_set_id, limit=1, offset=0).result
scoring_ids = [pl_records_resp["records"][0]["entity"]["values"]["scoring_id"]]
print("Running explanations on scoring IDs: {}".format(scoring_ids))
explanation_types = ["lime", "contrastive"]
result = wos_client.monitor_instances.explanation_tasks(scoring_ids=scoring_ids, explanation_types=explanation_types).result
print(result)
# Out:
# Running explanations on scoring IDs: ['291863422122685c0cc8cf0b5b32af61-1']
# {
#   "metadata": {
#     "explanation_task_ids": [
#       "9ae84790-8fc7-49a9-88b5-f47acd11c0a8"
#     ],
#     "created_by": "1000331030",
#     "created_at": "2022-09-12T20:07:01.436229Z"
#   }
# }

# %% [markdown]
# # Custom monitors and metrics <a name="custom"></a>

# %% [markdown]
# # Historical data <a name="historical"></a>
